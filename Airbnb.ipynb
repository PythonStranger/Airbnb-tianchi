# %%
import pandas as pd

# %%
listing = pd.read_csv("listings.csv")
calendar = pd.read_csv("calendar_detail.csv")
neighbourhoods=pd.read_csv("neighbourhoods.csv")
reviews_detail = pd.read_csv("reviews_detail.csv")
reviews = pd.read_csv("reviews.csv")

# %%
listing.head()
# Out:
#        id                                         name  host_id  \
# 0   44054         Modern and Comfortable Living in CBD   192875
# 1  100213  The Great Wall Box Deluxe Suite A团园长城小院东院套房   527062
# 2  128496          Heart of Beijing: House with View 2   467520
# 3  161902             cozy studio in center of Beijing   707535
# 4  162144            nice studio near subway, sleep 4    707535
#
#          host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0  East Apartments                  NaN  朝阳区 / Chaoyang  39.89503  116.45163
# 1              Joe                  NaN     密云县 / Miyun  40.68434  117.17231
# 2            Cindy                  NaN             东城区  39.93213  116.42200
# 3           Robert                  NaN             东城区  39.93357  116.43577
# 4           Robert                  NaN  朝阳区 / Chaoyang  39.93668  116.43798
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0     1165040  2019-04-17         f  $511.00        $511.00             1.0
# 1     1165040  2019-04-18         t  $511.00        $511.00             1.0
# 2     1165040  2019-04-19         t  $511.00        $511.00             1.0
# 3     1165040  2019-04-20         t  $511.00        $511.00             1.0
# 4     1165040  2019-04-21         t  $511.00        $511.00             1.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
neighbourhoods
# Out:
#     neighbourhood_group     neighbourhood
# 0                   NaN               东城区
# 1                   NaN     丰台区 / Fengtai
# 2                   NaN      大兴区 / Daxing
# 3                   NaN       密云县 / Miyun
# 4                   NaN      平谷区 / Pinggu
# 5                   NaN     延庆县 / Yanqing
# 6                   NaN     怀柔区 / Huairou
# 7                   NaN               房山区
# 8                   NaN               昌平区
# 9                   NaN    朝阳区 / Chaoyang
# 10                  NaN               海淀区
# 11                  NaN              石景山区
# 12                  NaN               西城区
# 13                  NaN    通州区 / Tongzhou
# 14                  NaN  门头沟区 / Mentougou
# 15                  NaN      顺义区 / Shunyi

# %%
reviews_detail.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       44054    84748  2010-08-25       207019        Jarrod
# 1       44054   118384  2010-10-13       218723      Kimberly
# 2       44054   436978  2011-08-11       609177          Emma
# 3       44054  1118657  2012-04-12      1787536      Andreyna
# 4       44054  2140650  2012-08-30      1179565       Frances
#
#                                             comments
# 0  Sev was very helpful.  Sev showed us where to ...
# 1  We arrived in Beijing very early in the mornin...
# 2  It is a really massive apartment and really co...
# 3  Sev was incredibly helpful, showed us around t...
# 4  The appartment was ideal for our party of 6 ad...

# %%
reviews.head()
# Out:
#    listing_id        date
# 0       44054  2010-08-25
# 1       44054  2010-10-13
# 2       44054  2011-08-11
# 3       44054  2012-04-12
# 4       44054  2012-08-30

# %%
calendar.merge(reviews_detail,on = ['listing_id'])
# Out:
#           listing_id      date_x available    price adjusted_price  \
# 0            1165040  2019-04-17         f  $511.00        $511.00
# 1            1165040  2019-04-17         f  $511.00        $511.00
# 2            1165040  2019-04-17         f  $511.00        $511.00
# 3            1165040  2019-04-17         f  $511.00        $511.00
# 4            1165040  2019-04-17         f  $511.00        $511.00
# 5            1165040  2019-04-17         f  $511.00        $511.00
# 6            1165040  2019-04-17         f  $511.00        $511.00
# 7            1165040  2019-04-17         f  $511.00        $511.00
# 8            1165040  2019-04-17         f  $511.00        $511.00
# 9            1165040  2019-04-17         f  $511.00        $511.00
# 10           1165040  2019-04-17         f  $511.00        $511.00
# 11           1165040  2019-04-17         f  $511.00        $511.00
# 12           1165040  2019-04-18         t  $511.00        $511.00
# ...

# %%
reviews_detail.shape
# Out:
# (202099, 6)

# %%
calendar.shape
# Out:
# (10384980, 7)
